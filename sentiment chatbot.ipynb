# %%
from textblob import TextBlob
import random

# %%
print("Hello buddy, what's your name?!🤔")
name = input()
print('Do you have a nickname?! [y/n] 🙃')
ans = input()
if 'y' in ans.lower():
  print("What's your nickname?!😍")
  nickname = input()
  print('Good to meet you ' + nickname + '😁')
else:
  name_list = ['nugget', 'dude','kiddo','buttercup','rambo','peanut','naruto','big wheel','capitalist','bunny',
               'Rue','Mikasa','Lez','Eren','Levi']
  nickname = random.choice(name_list)
  print('I will call you '+nickname + '😜')

greetings = [
    'How are you today ' + nickname + '?',
    'Howdy ' + nickname + " friend, how you feelin' today?",
    "What's up " + nickname + '?',
    'Greetings ' + nickname + ' are you well?',
    'How are things going ' + nickname + '?'
]
print(random.choice(greetings))
ans = input()
blob = TextBlob(ans)

if blob.polarity > 0:
  print('Glad you are doing well!😊')
else:
  print('Sorry to hear that! 😔')


topics = [
    'cricket',
    'coding',
    'java',
    'Python',
    'Computer Games',
    'cryptocurrency',
    ]

questions = [
    'What is your take on ',
    'What do u think about ',
    'How do u feel about ',
    'What do u reckon about ',
    'I would like your opinion on '
]
for i in range(0, random.randint(3, 4)):
  question = random.choice(questions)
  questions.remove(question)
  topic = random.choice(topics)
  topics.remove(topic)
  print(question + topic+'?')
  ans = input()
  blob = TextBlob(ans)

  if blob.polarity > 0.5:
    print("OMG, you really love "+topic)
  elif blob.polarity > 0.5:
    print("Well, you clearly like "+topic)
  elif blob.polarity < -0.5:
    print("Uff, you totally hate "+topic)
  elif blob.polarity < -0.1:
    print("So you don't like "+topic)
  else:
    print('That is a very neutral view on '+topic)

  if blob.subjectivity > 0.6:
    print('and you are so biased!')
  elif blob.subjectivity > 0.3:
    print('and you are bit biased!')
  else:
    print('and you are quite objective, huh!')

goodbyes = [
    'It was good talking to u ' + nickname + 'I gotta go now!',
    "OK I'm bored, I go watch NetFlix",
    "Bye Bye Buddy, I'm out!",
    "Catch ya later " + nickname
]

print(random.choice(goodbyes))
# Out:
# Hello buddy, what's your name?!🤔
# vishnu
# Do you have a nickname?! [y/n] 🙃
# n
# I will call you Lez😜
# How are things going Lez?
# mm its good
# Glad you are doing well!😊
# What is your take on Computer Games?
# i hate computer games
# Uff, you totally hate Computer Games
# and you are so biased!
# How do u feel about cricket?
# i love cricket very much
# That is a very neutral view on cricket
# and you are bit biased!
# What do u reckon about cryptocurrency?
# i dont know abt crypto
# That is a very neutral view on cryptocurrency
# and you are quite objective, huh!
# I would like your opinion on coding?
# i m very excited to do coding
# That is a very neutral view on coding
# and you are so biased!
# It was good talking to u LezI gotta go now!
